# %% [markdown]
# <a href="https://colab.research.google.com/github/adancalderon/MLintro/blob/main/Stats_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print("Python version: " + sys.version)

import numpy as np #******
print("numpy version: " + np.__version__)
import pandas as pd
print("pandas version: " + pd.__version__)

import matplotlib
import matplotlib.pyplot as plt #******
print("matplotlib: " + matplotlib.__version__)
# Out:
# Python version: 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
# numpy version: 1.19.5
# pandas version: 1.1.5
# matplotlib: 3.2.2

# %%
sampleDict = { "names" : ["Piper", "Todd"], 
              "fav food" : ["natto", "chocolate"], 
              "height" : [171, 164]  }

# %%
sampleDict["height"]
# Out:
# [171, 164]

# %%
n = np.arange(500)

#plt.plot(n, 2**n,'r-', label = "2^n")
plt.plot(n,n, 'r-', label ='n')
#plt.plot(n, 100+np.log2(n), 'g-', label = "100 +log n")
plt.plot(n, n* np.log2(n), 'b-', label = "n log n")
plt.plot(n, n**2, 'y-', label = "n^2")
#plt.plot(n, n**5, 'k-', label = "n^5")
#plt.plot(n, 20*n**4+1000, 'r-', label = "20n^4+1000")
plt.legend(edgecolor = "black")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log2
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in multiply

# %%
from sklearn.datasets import load_iris
iris = load_iris()

X = iris.data
y = iris.target

# %%
plt.scatter(X[:,2],X[:,3], c=y)
plt.colorbar()

# %%
t = list(range(0,100))
y = np.random.rand(100)

# %%
plt.plot(t,y)

# %%
np.std(y)
# Out:
# 0.28818354228142556

# %%
n = np.array(range(0,100))
plt.plot(n,n*np.log(n),'r')
plt.plot(n, n**2, 'b')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = data['c']+ np.abs(data['d']) * 10

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.colorbar()
plt.show()

# %%
from sklearn import preprocessing
X1 = preprocessing.normalize(X)

# %%
X1
# Out:
# array([[0.80377277, 0.55160877, 0.22064351, 0.0315205 ],
#        [0.82813287, 0.50702013, 0.23660939, 0.03380134],
#        [0.80533308, 0.54831188, 0.2227517 , 0.03426949],
#        [0.80003025, 0.53915082, 0.26087943, 0.03478392],
#        [0.790965  , 0.5694948 , 0.2214702 , 0.0316386 ],
#        [0.78417499, 0.5663486 , 0.2468699 , 0.05808704],
#        [0.78010936, 0.57660257, 0.23742459, 0.0508767 ],
#        [0.80218492, 0.54548574, 0.24065548, 0.0320874 ],
#        [0.80642366, 0.5315065 , 0.25658935, 0.03665562],
#        [0.81803119, 0.51752994, 0.25041771, 0.01669451],
#        [0.80373519, 0.55070744, 0.22325977, 0.02976797],
#        [0.786991  , 0.55745196, 0.26233033, 0.03279129],
#        [0.82307218, 0.51442011, 0.24006272, 0.01714734],
#        [0.8025126 , 0.55989251, 0.20529392, 0.01866308],
#        [0.81120865, 0.55945424, 0.16783627, 0.02797271],
#        [0.77381111, 0.59732787, 0.2036345 , 0.05430253],
# ...
